# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# Configura tus credenciales
CLIENT_ID = '02358e502eef43d1b64bace5c1110b75'
CLIENT_SECRET = '7a651087331f432ea143203910b95243'

# Autenticación
auth_manager = SpotifyClientCredentials(client_id=CLIENT_ID, client_secret=CLIENT_SECRET)
sp = spotipy.Spotify(auth_manager=auth_manager)

# Ejemplo: Buscar canciones de un artista
nombre_artista = 'Daft Punk'
resultados = sp.search(q=f'artist:{nombre_artista}', type='track', limit=5)

print(f"Top 5 canciones de {nombre_artista}:")
for i, track in enumerate(resultados['tracks']['items']):
    print(f"{i + 1}. {track['name']} - Álbum: {track['album']['name']}")
# Out:
# Top 5 canciones de Daft Punk:
# 1. Get Lucky (Radio Edit) [feat. Pharrell Williams and Nile Rodgers] - Álbum: Get Lucky (Radio Edit) [feat. Pharrell Williams and Nile Rodgers]
# 2. One More Time - Álbum: Discovery
# 3. Starboy - Álbum: Starboy
